# %% [markdown]
# <a href="https://colab.research.google.com/github/AgustinBustos/teaching/blob/main/intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # to learn
#
# data types:
# string,num,lists , dictionaries, booleano
# declare-call, bool and y or
# a='hi'
# b=4
# c=5.
# d=[1,4,'dfsa',a]
#
# loops: mismo codigo muchas veces
# for i in somelist:
#   this code runs multiple times but with different i
#   ...
#   ...
#
# conditionals
#
# if boolean:
#   run this code if boolean is true
#   ...
#   ...
# else:
#   run this code if boolean is false
#   ...
#   ...
#
#
#
# librerias
#
# funciones

# %% [markdown]
# # ex
#
# rock, paper, scissors
#
# fizz buzz
#
# https://aprendeconalf.es/docencia/python/ejercicios/bucles/

# %% [markdown]
# ## data types
#
# declaration (creates memory) = call (searches in memory)

# %%
# strings
nombre ='agus'
nombre2='botta'
nombre3='34'
nombre5="34"

#numeros
x=847
cualquiercosa=34
nombre4=78.689

# listas
mylista = [nombre,x,nombre5, [4,5],nombre4]
# mylista = list(range(424))
# mylista = list(range(200,424))

#booleano
hamburguesa=False
papa= (x==847)
papa= (x>800)


#dict
dd={
    'agus':26,
    'adan':24,
    'kev':26
    }



print(nombre2)
print(nombre)
print(x/2)
print(x*2)
# print(nombre/2)
print(nombre*200)
print(nombre*200)
print(nombre4*cualquiercosa)

print(mylista)
print(nombre+nombre2)
print(hamburguesa)
print(papa)
# Out:
# botta
# agus
# 423.5
# 1694
# ...
# ...
# 2675.426
# ['agus', 847, '34', [4, 5], 78.689]
# agusbotta
# False
# True

# %% [markdown]
# ## operations

# %%
print('hi')
# Out:
# hi

# %%
str: +, [idx],[:idx],.replace(),.split(),==, in
int: +,-,*,/,**,<,>,==
list: +,.join(),[idx],[:idx],.append(),x in l
dict: d['k'],d.keys()
bool: and, or,not

# %%
strs='hola agus'
str2='otro'

resultado=strs+str2
resultado=strs.replace('ol','fdsa')
resultado=strs.split(' ')




resultado
# Out:
# ['hola', 'agus']

# %% [markdown]
# ## conditionals
#
# if booleanvar:
#   ...
#   ...
# else:
#   ...
#   ...

# %%
boleano = (4>5)
boleano
asdf
asdf

if boleano:
  print('asdf')
  asdf
  asdf
  asdf
  asdf
  asdf
else:
  print('other')
  asdfasdf
  asdfasdf
sadkfu
asdf
asf

# %%
if hamburguesa:
  print('asdfkjh')
else:
  print('hago otra cosa')
# Out:
# hago otra cosa

# %%
j=7
h=str(j)

print(j+j+9)
print(h+h)
print('tengo '+h)
print(6+j)
print('tengo '+str(j))
# Out:
# 23
# 77
# tengo 7
# 13
# tengo 7

# %%
go=(6>8)
if (6>8):
  print('algo')
else:
  print('asdf')
# Out:
# asdf

# %% [markdown]
# ## loops
# range(10)
# for i in somelist:
#   ...
#   ...
#   ...

# %%
nombre8=56       #1

micheckeoasdjpa=(nombre8 == 78)
if micheckeoasdjpa:
  print('es 78!')
else:
  print('no es 78')
# Out:
# no es 78

# %%
for nombre8 in [1,78,56]:
  micheckeoasdjpa=(nombre8 == 78)
  if micheckeoasdjpa:
    print('es 78!')
  else:
    print('no es 78')
# Out:
# no es 78
# es 78!
# no es 78

# %%
url='https://hola.com/'

titulo='spider man' #'asdf etr'

resultado=url+titulo
resultado=resultado.replace(' ','%')
resultado
# Out:
# 'https://hola.com/spider%man'

# %%
url='https://hola.com/'
for titulo in ['spider man','asdf etr']:
  resultado=url+titulo
  resultado=resultado.replace(' ','%')
# Out:
# https://hola.com/spider%man
# https://hola.com/asdf%etr

# %%
billetes=[100,100,500,1000,10000,10]

total=0
for i in billetes:
  print(i)



print(total)
# Out:
# 100
# 100
# 500
# 1000
# 10000
# 10
# 0

# %% [markdown]
# ## functions
#
# def nameoffunction(parameter):
#   ...
#   ...
#   return result

# %%
type(hamburguesa)
type(nombre2)
type(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1524926696.py in <cell line: 0>()
# ----> 1 type(hamburguesa)
#       2 type(nombre2)
#       3 type(x)
#
# NameError: name 'hamburguesa' is not defined

# %%
listadenomeros=[3,4,5,2,]
sum(listadenomeros)
# Out:
# 14

# %% [markdown]
# ## libraries

# %%
# pyautogui

# %%
import pandas

# %%
import plotly.express

# %%
exel='/content/Media_test_StoreOverlay_v4.xlsx'

exel
# Out:
# '/content/Media_test_StoreOverlay_v4.xlsx'

# %%
oso=pandas.read_excel(exel)
oso
# Out:
#            Tactic                                      Variable  Coefficient  \
# 0       Circulars                      log_Dollars_per_Movement     0.649531
# 1       Circulars                  log_Quantity_per_transaction     0.867854
# 2       Circulars                            log_Total_Ad_Sales     0.042015
# 3       Circulars                       Seasonality_Index_Store     1.950300
# 4       Circulars  Circulars_Units_per100k_ret10_SAT95_D15_SC20     0.315478
# ...           ...                                           ...          ...
# 56381  Full Model                                      Store_64     0.143300
# 56382  Full Model                                      Store_68     0.749500
# 56383  Full Model                                      Store_84     0.901300
# 56384  Full Model                                       Store_9     1.440500
# 56385  Full Model                                      Store_97     0.095300
#
# ...

# %%
plotly.express.scatter(oso,x='Coefficient',y='t-stat',color='Tactic')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
